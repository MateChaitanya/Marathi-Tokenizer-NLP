# %%
#Develop a tokenization algorithm which can identify and extract (phrases/proverbs/Named Entities)

# %%
import os
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Function to read text from a file
def read_text_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# %%
# File path for the Marathi text file
file_path = "C:/Users/HP/Downloads/Marathi-Tokenizer-NLP"

# %%
# Read text data from the file
marathi_text = read_text_from_file(file_path)

# %%
# Tokenization function
def tokenize(text):
    tokens = word_tokenize(text)
    return tokens

# %%
# Named Entity Recognition function
def ner(text):
    words = word_tokenize(text)
    tagged = pos_tag(words)
    named_entities = ne_chunk(tagged)
    return named_entities

# %%
# Phrase Extraction function
def extract_phrases(text):
    phrases = []
    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
    chunkParser = nltk.RegexpParser(chunkGram)
    chunked = chunkParser.parse(tagged)
    for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
        phrases.append(" ".join([token for token, pos in subtree.leaves()]))
    return phrases

# %%
print("Original Text:", marathi_text)
# Out:
# Original Text: 1. त्याचं वागणं खुप जोरात आहे.
# 2. माझ्याकडून त्यांना एक विशेष नम्र विनंती केली गेली होती.
# 3. आपलं प्रेम सदैव अद्वितीय असतं.
# 4. त्यांच्याशी वारंवार आपल्याला अभिप्राय सामायलं होतं.
# 5. तुम्हाला अनेक नव्हे तर काही निर्णय करायला हवं.
# 6. त्यांच्यावर आपलं विश्वास अत्यंत मोठं आहे.
# 7. ह्या क्षणात आपलं मन कसं आहे?
# 8. तुमचं काम सगळं तुमच्या प्रतिभेने झालं आहे.
# 9. मी तुमच्यासोबत कधीही सहमत नसून अशी कोणती गोड बातमी नसती.
# 10. आपल्या प्रेमाचा आणि समर्थाचा वातावरण आहे.
# 11. त्यांना आपल्या उद्दिष्टाच्या साध्यात आपल्या सामान्य विरोधात समस्या आल्याचं काहीही नव्हतं.
# 12. मला एक वेगळं विचार आहे, कारण मला त्यांना समजलं आहे.
# 13. आपलं अनुभव माझ्या अनुभवाशी सामायलं आहे.
# 14. तुम्हाला कोणती गोड वातावरण आहे?
# 15. त्यांनी तुम्हाला विशेष व्यक्ती म्हणून गर्वाने अभिनंदन केलं.
# 16. आपल्याला एक नवीन कार्यक्षेत्रात सामायलं करावं लागेल.
# 17. तुमचं काम सगळं तुमच्या प्रयत्नाने झालं आहे.
# 18. माझं विश्वास आहे की त्यांनी तुमच्यासाठी सगळं केलं आहे.
# ...

# %%
# Tokenization
tokens = tokenize(marathi_text)
print("Tokens:", tokens)
# Out:
# Tokens: ['1', '.', 'त्याचं', 'वागणं', 'खुप', 'जोरात', 'आहे', '.', '2', '.', 'माझ्याकडून', 'त्यांना', 'एक', 'विशेष', 'नम्र', 'विनंती', 'केली', 'गेली', 'होती', '.', '3', '.', 'आपलं', 'प्रेम', 'सदैव', 'अद्वितीय', 'असतं', '.', '4', '.', 'त्यांच्याशी', 'वारंवार', 'आपल्याला', 'अभिप्राय', 'सामायलं', 'होतं', '.', '5', '.', 'तुम्हाला', 'अनेक', 'नव्हे', 'तर', 'काही', 'निर्णय', 'करायला', 'हवं', '.', '6', '.', 'त्यांच्यावर', 'आपलं', 'विश्वास', 'अत्यंत', 'मोठं', 'आहे', '.', '7', '.', 'ह्या', 'क्षणात', 'आपलं', 'मन', 'कसं', 'आहे', '?', '8', '.', 'तुमचं', 'काम', 'सगळं', 'तुमच्या', 'प्रतिभेने', 'झालं', 'आहे', '.', '9', '.', 'मी', 'तुमच्यासोबत', 'कधीही', 'सहमत', 'नसून', 'अशी', 'कोणती', 'गोड', 'बातमी', 'नसती', '.', '10', '.', 'आपल्या', 'प्रेमाचा', 'आणि', 'समर्थाचा', 'वातावरण', 'आहे', '.', '11', '.', 'त्यांना', 'आपल्या', 'उद्दिष्टाच्या', 'साध्यात', 'आपल्या', 'सामान्य', 'विरोधात', 'समस्या', 'आल्याचं', 'काहीही', 'नव्हतं', '.', '12', '.', 'मला', 'एक', 'वेगळं', 'विचार', 'आहे', ',', 'कारण', 'मला', 'त्यांना',
# ...

# %%
# Named Entity Recognition
named_entities = ner(marathi_text)
print("Named Entities:", named_entities)
# Out:
# Named Entities: (S
#   1/CD
#   ./.
#   त्याचं/VB
#   वागणं/JJ
#   खुप/NNP
#   जोरात/NNP
#   आहे/NNP
#   ./.
#   2/CD
#   ./.
#   माझ्याकडून/VB
#   त्यांना/JJ
#   एक/NNP
#   विशेष/NNP
#   नम्र/NNP
#   विनंती/NNP
#   केली/NNP
#   गेली/NNP
#   होती/NNP
#   ./.
#   3/CD
#   ./.
#   आपलं/VB
#   प्रेम/JJ
#   सदैव/NNP
#   अद्वितीय/NNP
#   असतं/NNP
#   ./.
#   4/CD
#   ./.
#   त्यांच्याशी/VB
#   वारंवार/JJ
#   आपल्याला/NNP
#   अभिप्राय/NNP
#   सामायलं/NNP
#   होतं/NNP
#   ./.
#   5/CD
#   ./.
#   तुम्हाला/VB
#   अनेक/JJ
#   नव्हे/NNP
#   तर/NNP
#   काही/NNP
#   निर्णय/NNP
#   करायला/NNP
#   हवं/NNP
#   ./.
#   6/CD
#   ./.
#   त्यांच्यावर/VB
#   आपलं/JJ
#   विश्वास/NNP
#   अत्यंत/NNP
#   मोठं/NNP
#   आहे/NNP
#   ./.
#   7/CD
#   ./.
#   ह्या/VB
#   क्षणात/JJ
#   आपलं/NNP
#   मन/NNP
#   कसं/NNP
#   आहे/NNP
#   ?/.
#   8/CD
#   ./.
#   तुमचं/VB
#   काम/JJ
#   सगळं/NNP
#   तुमच्या/NNP
#   प्रतिभेने/NNP
#   झालं/NNP
#   आहे/NNP
#   ./.
#   9/CD
#   ./.
#   मी/VB
#   तुमच्यासोबत/JJ
# ...

# %%
# Phrase Extraction
phrases = extract_phrases(marathi_text)
print("Phrases:", phrases)
# Out:
# Phrases: ['खुप जोरात आहे', 'एक विशेष नम्र विनंती केली गेली होती', 'सदैव अद्वितीय असतं', 'आपल्याला अभिप्राय सामायलं होतं', 'नव्हे तर काही निर्णय करायला हवं', 'विश्वास अत्यंत मोठं आहे', 'आपलं मन कसं आहे', 'सगळं तुमच्या प्रतिभेने झालं आहे', 'कधीही सहमत नसून अशी कोणती गोड बातमी नसती', 'आणि समर्थाचा वातावरण आहे', 'उद्दिष्टाच्या साध्यात आपल्या सामान्य विरोधात समस्या आल्याचं काहीही नव्हतं', 'वेगळं विचार आहे', 'कारण मला त्यांना समजलं आहे', 'माझ्या अनुभवाशी सामायलं आहे', 'गोड वातावरण आहे', 'विशेष व्यक्ती म्हणून गर्वाने अभिनंदन केलं', 'नवीन कार्यक्षेत्रात सामायलं करावं लागेल', 'सगळं तुमच्या प्रयत्नाने झालं आहे', 'आहे की त्यांनी तुमच्यासाठी सगळं केलं आहे', 'मला सदैव उघडलं आहे', 'माझ्याकडून दूर आहे', 'माझ्यासाठी मोठं मूळ आहे', 'येण्याची निर्णय घेतली आहे', 'माझ्यासाठी महत्त्वाचं आहे', 'माझ्यासाठी मोठा आहे', 'खुप अद्भुत काम केलं आहे', 'करा', 'आपल्या अभिप्रायाला महत्त्व द्या', 'माझ्याकडून सामायलं केलं आहे', 'सातत्याने चालत असलं तर तुमच्या धर्माला खुप अधिक मान्यता मिळेल', 'खुप गोड मारलं', 'पण मी अजू
# ...
